# %% [markdown]
# ## DSA 610 Project 1 (Code)
# #### by Kevin Black

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.ExcelFile('BW_MBA_data.xlsx')
data.sheet_names
# Out:
# ['Source', 'MBA Data', 'Undergraduate Data']

# %%
mba = pd.read_excel(data, 'MBA Data')
ug = pd.read_excel(data, 'Undergraduate Data')

# %%
mba
# Out:
#    Fulltime Business Week Ranking                      School Name  \
# 0                               1            University of Chicago
# 1                               2               Harvard University
# 2                               3          Northwestern University
# 3                               4       University of Pennsylvania
# 4                               5           University of Michigan
# ..                            ...                              ...
# 65                     Not Ranked            University of Georgia
# 66                     Not Ranked              University of Miami
# 67                     Not Ranked         University of Pittsburgh
# 68                     Not Ranked  University of Wisconsin-Madison
# 69                     Not Ranked           Wake Forest University
#
#              State     Type  Enrollment  Avg GMAT  Resident Tuition, Fees  \
# 0         Illinois  Private        1144     713.0                 97165.0
# ...

# %%
mba2 = mba[['Pct Asian American', 'Pct Minority']]

# %%
mba2.dropna()
# Out:
#     Pct Asian American  Pct Minority
# 0                 16.0           7.0
# 2                 25.0          13.0
# 3                  7.8           9.0
# 4                 21.0          13.0
# 6                 12.0          13.0
# ..                 ...           ...
# 64                 4.0          11.0
# 66                19.0          21.0
# 67                 1.5           7.0
# 68                 6.0           9.0
# 69                 8.0           8.0
#
# [63 rows x 2 columns]

# %%
mba.shape
mba.
# Out:
# (70, 13)

# %%
sns.barplot(data=mba, x='Type', y='Avg starting base salary')
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Avg starting base salary'>

# %%
mba.shape
# Out:
# (70, 13)

# %%
mba.isna().sum()
# Out:
# Fulltime Business Week Ranking    0
# School Name                       0
# State                             0
# Type                              0
# Enrollment                        0
# Avg GMAT                          3
# Resident Tuition, Fees            2
# Pct International                 2
# Pct Female                        2
# Pct Asian American                7
# Pct Minority                      4
# Pct with job offers               3
# Avg starting base salary          3
# dtype: int64

# %%
mba = mba.dropna()

# %%
mba.shape
# Out:
# (60, 13)

# %%
ug.head()
# Out:
#    2009 Rank  2008 Rank               School Name          Location     Type  \
# 0          1        2.0       Virginia (McIntire)   Charlottesville   Public
# 1          2        3.0      Notre Dame (Mendoza)  South Bend, Ind.  Private
# 2          3        1.0    Pennsylvania (Wharton)      Philadelphia  Private
# 3          4        6.0           Michigan (Ross)         Ann Arbor   Public
# 4          5        7.0  Brigham Young (Marriott)       Provo, Utah  Private
#
#    Program Length  Annual Cost  Fulltime enrollment  Student Rank  \
# 0               2         9490                  655             1
# 1               3        36847                 1669             2
# 2               4        37526                 2528            13
# 3               3        10848                 1050            18
# 4               2         4110                 1783             6
#
#    Recruiter Rank  Median Starting Salary  MBA Feeder Rank  \
# ...

# %%
ug.shape
# Out:
# (102, 19)

# %%
ug.isna().sum()
# Out:
# 2009 Rank                      0
# 2008 Rank                     21
# School Name                    0
# Location                       0
# Type                           0
# Program Length                 0
# Annual Cost                    0
# Fulltime enrollment            0
# Student Rank                   0
# Recruiter Rank                 0
# Median Starting Salary         0
# MBA Feeder Rank                0
# Academic Quality Rank          0
# Faculty Student Ratio          0
# Average SAT Score              0
# Average ACT Score              0
# Teaching Quality Grade         0
# Facilities & Service Grade     0
# Job Placement Grade            0
# dtype: int64

# %%
ug.dropna().shape
# Out:
# (81, 19)

# %%
# removed 2008 rank because its the only column with missing values
ug = ug.drop(['2008 Rank'], axis=1)

# %%
ug.head()
# Out:
#    2009 Rank               School Name          Location     Type  \
# 0          1       Virginia (McIntire)   Charlottesville   Public
# 1          2      Notre Dame (Mendoza)  South Bend, Ind.  Private
# 2          3    Pennsylvania (Wharton)      Philadelphia  Private
# 3          4           Michigan (Ross)         Ann Arbor   Public
# 4          5  Brigham Young (Marriott)       Provo, Utah  Private
#
#    Program Length  Annual Cost  Fulltime enrollment  Student Rank  \
# 0               2         9490                  655             1
# 1               3        36847                 1669             2
# 2               4        37526                 2528            13
# 3               3        10848                 1050            18
# 4               2         4110                 1783             6
#
#    Recruiter Rank  Median Starting Salary  MBA Feeder Rank  \
# 0              52                   58000                5
# ...

# %%
ug[ug.duplicated()]
# Out:
#     2009 Rank   School Name Location    Type  Program Length  Annual Cost  \
# 51         51  Georgia Tech  Atlanta  Public               4         5518
#
#     Fulltime enrollment  Student Rank  Recruiter Rank  Median Starting Salary  \
# 51                 1291            31              45                   50500
#
#     MBA Feeder Rank  Academic Quality Rank  Faculty Student Ratio  \
# 51               51                     66                   27.0
#
#     Average SAT Score  Average ACT Score Teaching Quality Grade  \
# 51               1270                 28                   B
#
#    Facilities & Service Grade Job Placement Grade
# 51                       A                   A

# %%
ug[ug['School Name'] == 'Georgia Tech']
# Out:
#     2009 Rank   School Name Location    Type  Program Length  Annual Cost  \
# 50         51  Georgia Tech  Atlanta  Public               4         5518
# 51         51  Georgia Tech  Atlanta  Public               4         5518
#
#     Fulltime enrollment  Student Rank  Recruiter Rank  Median Starting Salary  \
# 50                 1291            31              45                   50500
# 51                 1291            31              45                   50500
#
#     MBA Feeder Rank  Academic Quality Rank  Faculty Student Ratio  \
# 50               51                     66                   27.0
# 51               51                     66                   27.0
#
#     Average SAT Score  Average ACT Score Teaching Quality Grade  \
# 50               1270                 28                   B
# 51               1270                 28                   B
#
#    Facilities & Service Grade Job Placement Grade
# 50                       A                   A
# ...

# %%
# There is one duplicate row, so we will drop it.
ug = ug.drop_duplicates()

# %%
ug.head()
# Out:
#    2009 Rank               School Name          Location     Type  \
# 0          1       Virginia (McIntire)   Charlottesville   Public
# 1          2      Notre Dame (Mendoza)  South Bend, Ind.  Private
# 2          3    Pennsylvania (Wharton)      Philadelphia  Private
# 3          4           Michigan (Ross)         Ann Arbor   Public
# 4          5  Brigham Young (Marriott)       Provo, Utah  Private
#
#    Program Length  Annual Cost  Fulltime enrollment  Student Rank  \
# 0               2         9490                  655             1
# 1               3        36847                 1669             2
# 2               4        37526                 2528            13
# 3               3        10848                 1050            18
# 4               2         4110                 1783             6
#
#    Recruiter Rank  Median Starting Salary  MBA Feeder Rank  \
# 0              52                   58000                5
# ...

# %%
ug.shape
# Out:
# (101, 18)

# %%
sns.barplot(data = ug, x = 'Type', y = 'Median Starting Salary')
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Median Starting Salary'>

# %%
ug.corr()
# Out:
#                         2009 Rank  Program Length  Annual Cost  \
# 2009 Rank                1.000000        0.187553    -0.467271
# Program Length           0.187553        1.000000     0.260315
# Annual Cost             -0.467271        0.260315     1.000000
# Fulltime enrollment      0.300964        0.224296    -0.339149
# Student Rank             0.844298        0.184158    -0.262382
# Recruiter Rank           0.649866        0.226591    -0.122142
# Median Starting Salary  -0.785796        0.019359     0.423648
# MBA Feeder Rank          0.817140        0.202340    -0.352944
# Academic Quality Rank    0.840145        0.088909    -0.639303
# Faculty Student Ratio    0.580188        0.116267    -0.469795
# Average SAT Score       -0.751925       -0.123870     0.432817
# Average ACT Score       -0.779996       -0.028187     0.422529
#
#                         Fulltime enrollment  Student Rank  Recruiter Rank  \
# ...

# %%
sns.histplot(data=ug, x='Average SAT Score').set(title='Histogram of Average SAT Scores')
# Out:
# [Text(0.5, 1.0, 'Histogram of Average SAT Scores')]

# %%
ug[ug['School Name'].duplicated()]
# Out:
#     2009 Rank School Name      Location    Type  Program Length  Annual Cost  \
# 90         90     Rutgers  Newark, N.J.  Public               4        11457
# 94         94    Illinois       Chicago  Public               4        12716
#
#     Fulltime enrollment  Student Rank  Recruiter Rank  Median Starting Salary  \
# 90                 1608            84              78                   54000
# 94                 2025            92              89                   40000
#
#     MBA Feeder Rank  Academic Quality Rank  Faculty Student Ratio  \
# 90              100                     93                   39.0
# 94               66                     74                   28.0
#
#     Average SAT Score  Average ACT Score Teaching Quality Grade  \
# 90               1064                 23                   C
# 94               1130                 24                   C
#
#    Facilities & Service Grade Job Placement Grade
# 90                       B                   B
# ...

# %%
# There are 2 "Rutgers". One is in New Brunswick, the other in Newark. They differ drastically in rankings.
ug[ug['School Name'] == 'Rutgers']
# Out:
#     2009 Rank School Name             Location    Type  Program Length  \
# 56         56     Rutgers  New Brunswick, N.J.  Public               4
# 90         90     Rutgers         Newark, N.J.  Public               4
#
#     Annual Cost  Fulltime enrollment  Student Rank  Recruiter Rank  \
# 56        12070                 1010            93              27
# 90        11457                 1608            84              78
#
#     Median Starting Salary  MBA Feeder Rank  Academic Quality Rank  \
# 56                   55000               22                     50
# 90                   54000              100                     93
#
#     Faculty Student Ratio  Average SAT Score  Average ACT Score  \
# 56                   45.0               1336                 31
# 90                   39.0               1064                 23
#
#    Teaching Quality Grade Facilities & Service Grade Job Placement Grade
# 56                   C                          C                   B
# ...

# %%
# There are also 2 schools named "Illinois", one in Urbana-Champaign, the other in Chicago. They also differ drastically in rank.
ug[ug['School Name']=='Illinois']
# Out:
#     2009 Rank School Name          Location    Type  Program Length  \
# 21         22    Illinois  Urbana-Champaign  Public               4
# 94         94    Illinois           Chicago  Public               4
#
#     Annual Cost  Fulltime enrollment  Student Rank  Recruiter Rank  \
# 21        13394                 2850            28               7
# 94        12716                 2025            92              89
#
#     Median Starting Salary  MBA Feeder Rank  Academic Quality Rank  \
# 21                   54000               23                     40
# 94                   40000               66                     74
#
#     Faculty Student Ratio  Average SAT Score  Average ACT Score  \
# 21                   21.1               1340                 30
# 94                   28.0               1130                 24
#
#    Teaching Quality Grade Facilities & Service Grade Job Placement Grade
# 21                   C                          A                    A+
# ...

# %%
# We can also see here that the acadmeic quality rank and MBA feeder rank have a positive relationship.
sns.regplot(data=ug, x='MBA Feeder Rank', y='Academic Quality Rank')
# Out:
# <AxesSubplot:xlabel='MBA Feeder Rank', ylabel='Academic Quality Rank'>

# %%
sns.regplot(data=ug, x='2009 Rank', y='Average SAT Score').set(title='2009 Ranking by Avg SAT Score')
# Out:
# [Text(0.5, 1.0, '2009 Ranking by Avg SAT Score')]

# %%
sns.barplot(data=ug, x='Type', y='Average SAT Score').set(title='Average SAT Score by School Type', xlabel='School Type')
# Out:
# [Text(0.5, 1.0, 'Average SAT Score by School Type'),
#  Text(0.5, 0, 'School Type')]

# %%
sns.relplot(data=ug, x='2009 Rank', y='')

# %%
sns.barplot(data=ug, x='Type', y='Median Starting Salary').set(title='Median Starting Salary for Public and Private Schools', xlabel='School Type')
# Out:
# [Text(0.5, 1.0, 'Median Starting Salary for Public and Private Schools'),
#  Text(0.5, 0, 'School Type')]

# %%
sns.histplot(data=ug, x='Median Starting Salary').set(title='Histogram of Median Starting Salaries')
# Out:
# [Text(0.5, 1.0, 'Histogram of Median Starting Salaries')]

# %%
sns.regplot(data=ug, x='Median Starting Salary', y='2009 Rank').set(title='Median Startin Salary vs. 2009 Ranking', ylabel='2009 Ranking (1st place to 100th place)')
# Out:
# [Text(0.5, 1.0, 'Median Startin Salary vs. 2009 Ranking'),
#  Text(0, 0.5, '2009 Ranking (1st place to 100th place)')]

# %%
sns.regplot(data=ug, x='2009 Rank', y='Average SAT Score').set(title='Average SAT score vs. School Ranking', xlabel='2009 School Ranking')
# Out:
# [Text(0.5, 1.0, 'Average SAT score vs. School Ranking'),
#  Text(0.5, 0, '2009 School Ranking')]
